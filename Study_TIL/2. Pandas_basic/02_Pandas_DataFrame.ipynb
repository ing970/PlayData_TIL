# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>

# %%
#1. data/movie.csv 를 읽어서 변수 movie에 할당.
movie = pd.read_csv('data/movie.csv')
movie.head() # 앞에 5행 조회
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#2. 1의 데이터프레임을 csv 파일로 저장(파일명 : saved_data/movie_df.csv)
movie.to_csv('saved_data/movie_df.csv', index = False)
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#3. 1의 데이터프레임을 엑셀파일로 저장(파일명 : saved_data/movie_df.xlsx)
movie.to_excel('saved_data/movie_df.xlsx', index = False)
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#4. 3에서 저장한 movie_df1.xlsx 파일을 읽어서 m_df 변수에 할당
m_df = pd.read_excel('saved_data/movie_df.xlsx') 
m_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>
# - 패스 여부를 boolean값으로 저장하는 파생변수 열을 추가
#     - 열이름: pass
#     - 평균점수가 80미만이면 False,이상이면 True가 나오도록 처리

# %%
Pass 컬럼 만들기 (True, False 파생변수 넣기)

# %%
grade['Pass'] = grade['평균'] >= 80
grade
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass
# 0  id-1     100       90    90     100  380  95.0   True
# 1  id-2      50       80    90      20  240  60.0  False
# 2  id-3      70      100    90      50  310  77.5  False
# 3  id-4      60       60    90      60  270  67.5  False
# 4  id-5      90       40    90      40  260  65.0  False

# %%
import numpy as np

grade['Pass2'] = np.where(grade['평균'] >= 80, '통과', '낙제') # True: 통과, False: 낙제로 변경
grade
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 0  id-1     100       90    90     100  380  95.0   True    통과
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 3  id-4      60       60    90      60  270  67.5  False    낙제
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
g2 = grade

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>
# - 다음 movie dataframe을 이용해 코드를 작성

# %%
movie = pd.read_csv('data/movie.csv')
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# 1.  director_name 컬럼의 값들 조회
movie["director_name"]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
# 2. actor_1_name, actor_2_name, actor_3_name 컬럼의 값들 
movie[["actor_1_name", 'actor_2_name', 'actor_3_name']]
# or
movie.filter(regex=r'actor_[123]_name')
# Out:
#           actor_2_name     actor_1_name          actor_3_name
# 0     Joel David Moore      CCH Pounder             Wes Studi
# 1        Orlando Bloom      Johnny Depp        Jack Davenport
# 2         Rory Kinnear  Christoph Waltz      Stephanie Sigman
# 3       Christian Bale        Tom Hardy  Joseph Gordon-Levitt
# 4           Rob Walker      Doug Walker                   NaN
# ...                ...              ...                   ...
# 4911     Daphne Zuniga      Eric Mabius          Crystal Lowe
# 4912     Valorie Curry      Natalie Zea         Sam Underwood
# 4913     Maxwell Moody      Eva Boehnke        David Chandler
# 4914     Daniel Henney        Alan Ruck           Eliza Coupe
# 4915  Brian Herzlinger      John August              Jon Gunn
#
# [4916 rows x 3 columns]

# %%
# 3. 1, 3, 4, 7 번 컬럼 조회('director_name', 'duration', 'director_facebook_likes', 'actor_1_facebook_likes')
movie[['director_name', 'duration', 'director_facebook_likes', 'actor_1_facebook_likes']]
# or
movie[movie.columns[[1,3,4,7]]]
# Out:
#           director_name  duration  director_facebook_likes  \
# 0         James Cameron     178.0                      0.0
# 1        Gore Verbinski     169.0                    563.0
# 2            Sam Mendes     148.0                      0.0
# 3     Christopher Nolan     164.0                  22000.0
# 4           Doug Walker       NaN                    131.0
# ...                 ...       ...                      ...
# 4911        Scott Smith      87.0                      2.0
# 4912                NaN      43.0                      NaN
# 4913   Benjamin Roberds      76.0                      0.0
# 4914        Daniel Hsia     100.0                      0.0
# 4915           Jon Gunn      90.0                     16.0
#
#       actor_1_facebook_likes
# 0                     1000.0
# 1                    40000.0
# 2                    11000.0
# 3                    27000.0
# 4                      131.0
# ...                      ...
# 4911                   637.0
# ...

# %%
# 4. 1 ~ 5 번 컬럼 조회('director_name', 'num_critic_for_reviews', 'duration', director_facebook_likes', 'actor_3_facebook_likes')
movie[['director_name', 'num_critic_for_reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes']]
# or
movie[movie.columns[1:6]]
# Out:
#           director_name  num_critic_for_reviews  duration  \
# 0         James Cameron                   723.0     178.0
# 1        Gore Verbinski                   302.0     169.0
# 2            Sam Mendes                   602.0     148.0
# 3     Christopher Nolan                   813.0     164.0
# 4           Doug Walker                     NaN       NaN
# ...                 ...                     ...       ...
# 4911        Scott Smith                     1.0      87.0
# 4912                NaN                    43.0      43.0
# 4913   Benjamin Roberds                    13.0      76.0
# 4914        Daniel Hsia                    14.0     100.0
# 4915           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes
# 0                         0.0                   855.0
# 1                       563.0                  1000.0
# 2                         0.0                   161.0
# ...

# %% [markdown]
# ### 다양한 열선택 기능을 제공하는 메소드들
# - **`select_dtypes(include=[데이터타입,..], exclude=[데이터타입,..])`**
#     - 전달한 데이터 타입의 열들을 조회.
#     - include : 조회할 열 데이터 타입
#     - exclude : 제외하고 조회할 열 데이터 타입
# - **`filter (items=[], like='', regex='')`**
#    - 매개변수에 전달하는 열의 이름에 따라 조회
#     - 각 매개변수중 하나만 사용할 수 있다.
#     - **items = \[컬럼명들, ..\]**
#         - 리스트와 일치하는 열들 조회
#         - 이름이 일치 하지 않아도 Error 발생안함.
#     - **like = '부분일치문자열'**
#         - 전달한 문자열이 들어간 열들 조회
#         - 부분일치 개념
#     - **regex = '정규표현식'**
#         - 정규 표현식을 이용해 열명의 패턴으로 조회

# %%
g2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       5 non-null      object
#  1   KOREAN   5 non-null      int64
#  2   ENGLISH  5 non-null      int64
#  3   MATH     5 non-null      int64
#  4   PYTHON   5 non-null      int64
#  5   총점       5 non-null      int64
#  6   평균       5 non-null      float64
#  7   Pass     5 non-null      bool
#  8   Pass2    5 non-null      object
# dtypes: bool(1), float64(1), int64(5), object(2)
# memory usage: 365.0+ bytes

# %%
# 컬럼(Series)의 data type을 변경
g2['MATH'].astype('int32') # 원본을 바꾸지 않는다 / 단지 조회한 것이다.
# Out:
# 0    90
# 1    90
# 2    90
# 3    90
# 4    90
# Name: MATH, dtype: int32

# %%
g2['MATH'] = g2['MATH'].astype('int32') # 이렇게 구성해야 바꿔진다.

# %%
g2.select_dtypes(include= 'float64')
g2.select_dtypes(include= ['float64', 'int32'])
# Out:
#    MATH    평균
# 0    90  95.0
# 1    90  60.0
# 2    90  77.5
# 3    90  67.5
# 4    90  65.0

# %%
# 조회대상에서 제외하려는 타입을 지정.
g2.select_dtypes(exclude='int64')
g2.select_dtypes(exclude=['int64','int64'])
# Out:
#      id  MATH    평균   Pass Pass2
# 0  id-1    90  95.0   True    통과
# 1  id-2    90  60.0  False    낙제
# 2  id-3    90  77.5  False    낙제
# 3  id-4    90  67.5  False    낙제
# 4  id-5    90  65.0  False    낙제

# %%
# filter()
# g2['KOR'] # indexer는 없는 컬럼 조회시 Exception 발생(KeyError)
g2.filter(items='KOR') # 없는 컬럼 조회하면 Exception 발생하지 않고 무시.
g2.filter(items=['KOREAN','ENGLISH','MUSIC','PAINTING'])
# Out:
#    KOREAN  ENGLISH
# 0     100       90
# 1      50       80
# 2      70      100
# 3      60       60
# 4      90       40

# %%
g2.filter(like="PASS") # 컬럼명에 PASS가 들어간 컬럼을 조회.
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
g2.filter(regex='\w{5,}') # 컬럼명이 5글자 이상인 컬럼들을 조회
# Out:
#    KOREAN  ENGLISH  PYTHON Pass2
# 0     100       90     100    통과
# 1      50       80      20    낙제
# 2      70      100      50    낙제
# 3      60       60      60    낙제
# 4      90       40      40    낙제

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>
#
# 다음은 movie dataframe을 이용해 아래 코드를 작성하시오.
# movie = pd.read(save3

# %%
# 1. 정수형(int64) 컬럼만 조회
movie.select_dtypes(include=['int64'])
# Out:
#       num_voted_users  cast_total_facebook_likes  movie_facebook_likes
# 0              886204                       4834                 33000
# 1              471220                      48350                     0
# 2              275868                      11700                 85000
# 3             1144337                     106759                164000
# 4                   8                        143                     0
# ...               ...                        ...                   ...
# 4911              629                       2283                    84
# 4912            73839                       1753                 32000
# 4913               38                          0                    16
# 4914             1255                       2386                   660
# 4915             4285                        163                   456
#
# [4916 rows x 3 columns]

# %%
# 2. 정수형(int64)과 실수형(float64) 타입을 제외한 컬럼들만 조회
movie.select_dtypes(exclude=['int64', 'float64'])
# Out:
#       color      director_name      actor_2_name  \
# 0     Color      James Cameron  Joel David Moore
# 1     Color     Gore Verbinski     Orlando Bloom
# 2     Color         Sam Mendes      Rory Kinnear
# 3     Color  Christopher Nolan    Christian Bale
# 4       NaN        Doug Walker        Rob Walker
# ...     ...                ...               ...
# 4911  Color        Scott Smith     Daphne Zuniga
# 4912  Color                NaN     Valorie Curry
# 4913  Color   Benjamin Roberds     Maxwell Moody
# 4914  Color        Daniel Hsia     Daniel Henney
# 4915  Color           Jon Gunn  Brian Herzlinger
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...

# %%
# 3. actor_1_name, actor_2_name, actor_3_name 컬럼의 값을 조회
movie.filter(items=['actor_1_name', 'actor_2_name', 'actor_3_name'])
# or 
movie.filter(regex=r'actor_[123]_name')
# Out:
#           actor_2_name     actor_1_name          actor_3_name
# 0     Joel David Moore      CCH Pounder             Wes Studi
# 1        Orlando Bloom      Johnny Depp        Jack Davenport
# 2         Rory Kinnear  Christoph Waltz      Stephanie Sigman
# 3       Christian Bale        Tom Hardy  Joseph Gordon-Levitt
# 4           Rob Walker      Doug Walker                   NaN
# ...                ...              ...                   ...
# 4911     Daphne Zuniga      Eric Mabius          Crystal Lowe
# 4912     Valorie Curry      Natalie Zea         Sam Underwood
# 4913     Maxwell Moody      Eva Boehnke        David Chandler
# 4914     Daniel Henney        Alan Ruck           Eliza Coupe
# 4915  Brian Herzlinger      John August              Jon Gunn
#
# [4916 rows x 3 columns]

# %%
# 4. actor_1_facebook_likes, actor_1_name 컬럼의 값을 조회
movie.filter(items=['actor_1_facebook_likes', 'actor_1_name'])
# or
movie.filter(like='actor_1')
# Out:
#       actor_1_facebook_likes     actor_1_name
# 0                     1000.0      CCH Pounder
# 1                    40000.0      Johnny Depp
# 2                    11000.0  Christoph Waltz
# 3                    27000.0        Tom Hardy
# 4                      131.0      Doug Walker
# ...                      ...              ...
# 4911                   637.0      Eric Mabius
# 4912                   841.0      Natalie Zea
# 4913                     0.0      Eva Boehnke
# 4914                   946.0        Alan Ruck
# 4915                    86.0      John August
#
# [4916 rows x 2 columns]

# %%
# 5. color, director 컬럼을 조회. 없는 컬럼명이라도 에러가 안나도록 조회하시오.
movie.filter(items=['color', 'director'])
# Out:
#       color
# 0     Color
# 1     Color
# 2     Color
# 3     Color
# 4       NaN
# ...     ...
# 4911  Color
# 4912  Color
# 4913  Color
# 4914  Color
# 4915  Color
#
# [4916 rows x 1 columns]

# %%
# 6. movie가 들어가는 컬럼들을 조회.
movie.filter(like='movie')
# Out:
#                                      movie_title  \
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens
# ...                                          ...
# 4911                     Signed Sealed Delivered
# 4912                               The Following
# 4913                        A Plague So Pleasant
# 4914                            Shanghai Calling
# 4915                           My Date with Drew
#
#                                         movie_imdb_link  movie_facebook_likes
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...                 33000
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...                     0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 85000
# ...

# %% [markdown]
# ## 행 조회
#
# - **loc** :  index 이름으로 조회
# - **iloc** : 행 순번으로 조회

# %% [markdown]
# ### loc indexer
# - index name으로 조회
# - **`DF.loc[ index이름 ]`**
#     - 한 행 조회.
#     - 조회할 행 index 이름(레이블) 전달
#     - 이름이 문자열이면 " " 문자열표기법으로 전달. 정수이며 정수표기법으로 전달한다.
# - **`DF.loc[ index이름 리스트 ]`**
#     - 여러 행 조회.
#     - 팬시 인덱스
#     - 조회할 행 index 이름(레이블) 리스트 전달
# - **`DF.loc[start index이름 : end index이름: step]`**
#     - 슬라이싱 지원
#     - end index 이름의 행까지 포함한다.
# - **`DF.loc[index이름 , 컬럼이름]`**
#     - 행과 열 조회
#     - 둘다 이름으로 지정해야 함.

# %%
g2
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 0  id-1     100       90    90     100  380  95.0   True    통과
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 3  id-4      60       60    90      60  270  67.5  False    낙제
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
g2.loc[1]
"""
id          id-2
KOREAN        50
ENGLISH       80
MATH          90
PYTHON        20
총점           240
평균          60.0
Pass       False
Pass2         낙제
Name: 1, dtype: object
"""
# Out:
# id          id-2
# KOREAN        50
# ENGLISH       80
# MATH          90
# PYTHON        20
# 총점           240
# 평균          60.0
# Pass       False
# Pass2         낙제
# Name: 1, dtype: object

# %%
g2.loc[[1,2]] # fancy indexing
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 2  id-3      70      100    90      50  310  77.5  False    낙제

# %%
# 행조회는 slicing 지원
g2.loc[1:5] # stop index 도 포함 
g2.loc[1:5:2]
g2.loc[1:] # stop 생략 => 마지막 행까지 다 조회
g2.loc[:2] # start 생략 => 시작 행(0번 행) 부터 조회
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 0  id-1     100       90    90     100  380  95.0   True    통과
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 2  id-3      70      100    90      50  310  77.5  False    낙제

# %%
 # g2.loc[1]['KOREAN']
g2.loc[1,'KOREAN']
df.loc[ 행조회, 열조회] == 행/열 모두 이름
# Out:
# 50

# %%
g2.loc[[1,2, 4], '총점'] # 행: fancy indexing, 열: 하나를 지정
g2.loc[[1,2, 4], ['총점', '평균']] # 행: fancy indexing, 열: fancy indexing
g2.loc[1,:"PYTHON"]  # 행: 하나를 지정. 열:slicing(loc 에서는 열도 slicing 가능.)
# Out:
# ID         id-2
# KOREAN       50
# ENGLISH      80
# MATH         90
# PYTHON       20
# Name: 1, dtype: object

# %%
g2.loc[1:3,'ENGLISH':"평균"] # 행/열 모두 slicing
# Out:
#    ENGLISH  MATH  PYTHON   총점    평균
# 1       80    90      20  240  60.0
# 2      100    90      50  310  77.5
# 3       60    90      60  270  67.5

# %%
g2.loc[1,0] # 컬럼명이 0인 컬럼조회. loc index는 행/열 모두 이름으로 조회. Exception 발생.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### iloc
# - index(행 순번)으로 조회
# - **`DF.iloc[행번호]`**
#     - 한 행 조회.
#     - 조회할 행 번호 전달
# - **`DF.iloc[ 행번호 리스트 ]`**
#     - 여러 행 조회.
#     - 조회할 행 번호 리스트 전달
# - **`DF.iloc[start 행번호: stop 행번호: step]`**
#     - 슬라이싱 지원
#     - stop 행번호 포함 안함.
# - **`DF.iloc[행번호 , 열번호]`**
#     - 행과 열 조회
#     - 행열 모두 순번으로 지정

# %%
# g2[2] # 컬럼이 이름이 2인 열을 조회
g2.loc[2] #행(index)이름이 2인 행을 조회
g2.iloc[2] #index(순번) 이름이 2인 행을 조회
# Out:
# id          id-3
# KOREAN        70
# ENGLISH      100
# MATH          90
# PYTHON        50
# 총점           310
# 평균          77.5
# Pass       False
# Pass2         낙제
# Name: 2, dtype: object

# %%
g2.iloc[[2,1,4]] #fancy indexing : list 순번으로 조회
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
g2.iloc[-3:] # 뒤에서 3번쨰 행 ~ 끝까지 
g2.tail(3) # 위에 명령어랑 같음.
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 3  id-4      60       60    90      60  270  67.5  False    낙제
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
g2.iloc[::-1] # 리버스
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 4  id-5      90       40    90      40  260  65.0  False    낙제
# 3  id-4      60       60    90      60  270  67.5  False    낙제
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 1  id-2      50       80    90      20  240  60.0  False    낙제
# 0  id-1     100       90    90     100  380  95.0   True    통과

# %%
# g2.iloc[3,"ENGLISH"]  =>  iloc [행 순번, 열 순번] 으로 해야함.
                        # 둘다 수넙능ㄹ 이용해서 지정 (indexing slcing, facy indexing 문법 사용가능)

g2.iloc[3, 1]
g2.iloc[[1,3],[2,5]] # 열 2번 5번
g2.iloc[[1,3],:4] # 열 0 ~ 3번(4번은 포함하지 않음)
# Out:
#      id  KOREAN  ENGLISH  MATH
# 1  id-2      50       80    90
# 3  id-4      60       60    90

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>
# - movie dataframe을 이용해 loc과 iloc관련해 다음을 작성

# %%
# 1.  movie_title 컬럼을 index명으로 지정

# %%
df = movie.set_index('movie_title')
df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# or
movie1 = pd.read_csv('data/movie.csv', index_col= 'movie_title')
m = movie1
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
# 2.  행이름이 Avatar인 행 조회
df.loc['Avatar']
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                   723.0
# duration                                                                 178.0
# director_facebook_likes                                                    0.0
# actor_3_facebook_likes                                                   855.0
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                  1000.0
# gross                                                              760505847.0
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# num_voted_users                                                         886204
# ...

# %%
# 3.  행이름이 Spider-Man 3, The Avengers, Titanic 인 행 조회
df.loc[['Spider-Man 3', 'The Avengers', 'Titanic']]
# Out:
#               color  director_name  num_critic_for_reviews  duration  \
# movie_title
# Spider-Man 3  Color      Sam Raimi                   392.0     156.0
# The Avengers  Color    Joss Whedon                   703.0     173.0
# Titanic       Color  James Cameron                   315.0     194.0
#
#               director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Spider-Man 3                      0.0                  4000.0
# The Avengers                      0.0                 19000.0
# Titanic                           0.0                   794.0
#
#                    actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Spider-Man 3       James Franco                 24000.0  336530303.0
# The Avengers  Robert Downey Jr.                 26000.0  623279547.0
# Titanic            Kate Winslet                 29000.0  658672302.0
#
#                                 genres  ... num_user_for_reviews  language  \
# ...

# %%
# 4.  행이름 Spectre ~ Robin Hood 까지 범위로 조회
df.loc['Spectre':'Robin Hood']
# Out:
#                                              color      director_name  \
# movie_title
# Spectre                                      Color         Sam Mendes
# The Dark Knight Rises                        Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     NaN        Doug Walker
# John Carter                                  Color     Andrew Stanton
# Spider-Man 3                                 Color          Sam Raimi
# Tangled                                      Color       Nathan Greno
# Avengers: Age of Ultron                      Color        Joss Whedon
# Harry Potter and the Half-Blood Prince       Color        David Yates
# Batman v Superman: Dawn of Justice           Color        Zack Snyder
# Superman Returns                             Color       Bryan Singer
# Quantum of Solace                            Color       Marc Forster
# Pirates of the Caribbean: Dead Man's Chest   Color     Gore Verbinski
# ...

# %%
# 5.  행이름이 John Carter 이고 열이름이 director_name 인 값 조회 - John Carter의 감독이름
df.loc['John Carter', 'director_name']
# Out:
# 'Andrew Stanton'

# %%
# 6.  1번행 조회
df.iloc[0]
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                   723.0
# duration                                                                 178.0
# director_facebook_likes                                                    0.0
# actor_3_facebook_likes                                                   855.0
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                  1000.0
# gross                                                              760505847.0
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# num_voted_users                                                         886204
# ...

# %%
# 7.  마지막 행 조회
df.iloc[-1]
# Out:
# color                                                                    Color
# director_name                                                         Jon Gunn
# num_critic_for_reviews                                                    43.0
# duration                                                                  90.0
# director_facebook_likes                                                   16.0
# actor_3_facebook_likes                                                    16.0
# actor_2_name                                                  Brian Herzlinger
# actor_1_facebook_likes                                                    86.0
# gross                                                                  85222.0
# genres                                                             Documentary
# actor_1_name                                                       John August
# num_voted_users                                                           4285
# ...

# %%
# 8.  1, 2, 5, 6, 9 번행 조회
df.iloc[[1,2,5,6,9]]
# Out:
#                                           color   director_name  \
# movie_title
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes
# John Carter                               Color  Andrew Stanton
# Spider-Man 3                              Color       Sam Raimi
# Harry Potter and the Half-Blood Prince    Color     David Yates
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
# John Carter                                                462.0     132.0
# Spider-Man 3                                               392.0     156.0
# Harry Potter and the Half-Blood Prince                     375.0     153.0
#
#                                           director_facebook_likes  \
# movie_title
# ...

# %%
# 9.  10 ~ 20 행 조회
df.iloc[9:20]
# Out:
#                                              color     director_name  \
# movie_title
# Harry Potter and the Half-Blood Prince       Color       David Yates
# Batman v Superman: Dawn of Justice           Color       Zack Snyder
# Superman Returns                             Color      Bryan Singer
# Quantum of Solace                            Color      Marc Forster
# Pirates of the Caribbean: Dead Man's Chest   Color    Gore Verbinski
# The Lone Ranger                              Color    Gore Verbinski
# Man of Steel                                 Color       Zack Snyder
# The Chronicles of Narnia: Prince Caspian     Color    Andrew Adamson
# The Avengers                                 Color       Joss Whedon
# Pirates of the Caribbean: On Stranger Tides  Color      Rob Marshall
# Men in Black 3                               Color  Barry Sonnenfeld
#
#                                              num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
# 10.  movie dataframe에서 5 ~ 10 행의 color, director_name, num_critic_for_reviews 컬럼(0,1,2번째 컬럼)을 iloc을 이용해 조회


df.iloc[4:10, :3]
# Out:
#                                             color   director_name  \
# movie_title
# Star Wars: Episode VII - The Force Awakens    NaN     Doug Walker
# John Carter                                 Color  Andrew Stanton
# Spider-Man 3                                Color       Sam Raimi
# Tangled                                     Color    Nathan Greno
# Avengers: Age of Ultron                     Color     Joss Whedon
# Harry Potter and the Half-Blood Prince      Color     David Yates
#
#                                             num_critic_for_reviews
# movie_title
# Star Wars: Episode VII - The Force Awakens                     NaN
# John Carter                                                  462.0
# Spider-Man 3                                                 392.0
# Tangled                                                      324.0
# Avengers: Age of Ultron                                      635.0
# Harry Potter and the Half-Blood Prince                       375.0

# %% [markdown]
# ## Boolean indexing을 이용한 조회
# - 원하는 조건을 만족하는 행, 열을 조회한다.
#
# - **`DataFrame객체[조건], DataFrame객체.loc[조건]`**
#     - 조건이 True인 행만 조회
#     - 열까지 선택시
#         - `DataFrame객체[조건][열]`
#         - `DataFrame객체.loc[조건, 열]`
# - **iloc indexer**는 boolean indexing을 **지원하지 않는다.**
#
# > - 논리연산자
# > |논리연산자|설명|
# > |:-:|-|
# > |&|and연산|
# > |\||or연산|
# > |~|not 연산|
#
# > - 논리연산자의 피연산자들은 반드시 ( )로 묶어준다.
# > - 파이썬과는 다르게 `and`, `or`, `not` 예약어는 사용할 수 없다.

# %%
g2[[True,False,False,False,True]] # 행조회
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 0  id-1     100       90    90     100  380  95.0   True    통과
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
# 국어점수가 80이상인 행을 조회
g2[g2['KOREAN'] >= 80]
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 0  id-1     100       90    90     100  380  95.0   True    통과
# 4  id-5      90       40    90      40  260  65.0  False    낙제

# %%
# 국어가 60~80 사이인 행들
g2[(g2['KOREAN'] >= 60) & (g2['KOREAN'] <=80)]
g2[g2['KOREAN'].between(60,80)]
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 2  id-3      70      100    90      50  310  77.5  False    낙제
# 3  id-4      60       60    90      60  270  67.5  False    낙제

# %%
# 국어가 60~80 사이이고 영어가 100점인 행들
g2[(g2['KOREAN'] >= 60) & (g2['KOREAN'] <=80) & (g2['ENGLISH'] == 100)]
# Out:
#      id  KOREAN  ENGLISH  MATH  PYTHON   총점    평균   Pass Pass2
# 2  id-3      70      100    90      50  310  77.5  False    낙제

# %%
# 국어가 60~80 사이이고 영어가 100점인 행들의 국어, 영어, 평균점수를 확인
g2[(g2['KOREAN'] >= 60) & (g2['KOREAN'] <=80) & (g2['ENGLISH'] == 100)][['KOREAN', "ENGLISH", "평균"]]
# Out:
#    KOREAN  ENGLISH    평균
# 2      70      100  77.5

# %%
# df.loc [행 -> boolen index, 열]
g2.loc[g2['KOREAN'].between(60,80) & (g2['ENGLISH'] ==100), ['KOREAN', "ENGLISH", "평균"]]
# Out:
#    KOREAN  ENGLISH    평균
# 2      70      100  77.5

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>

# %%
# movie dataframe의 index명을 컬럼 설정한다.
df.reset_index(inplace=True)

# %%
# 1.  상영시간 (duration)이 300 이상인 영화들 조회
df[df['duration'] >= 300]
# Out:
#                    movie_title  color        director_name  \
# 1134             Heaven's Gate  Color       Michael Cimino
# 1487       Blood In, Blood Out  Color      Taylor Hackford
# 1694                   Trapped  Color                  NaN
# 2436                    Carlos  Color                  NaN
# 3254  The Legend of Suriyothai  Color  Chatrichalerm Yukol
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 1134                   102.0     325.0                    517.0
# 1487                    12.0     330.0                    138.0
# 1694                    16.0     511.0                      NaN
# 2436                   108.0     334.0                      NaN
# 3254                    31.0     300.0                      6.0
#
#       actor_3_facebook_likes              actor_2_name  \
# 1134                   678.0             Sam Waterston
# 1487                   672.0             Jesse Borrego
# ...

# %%
# 2.  상영시간 (duration)이 300 이상인 영화들의 영화제목(movie_title)과 감독이름(director_name) 조회
df.loc[(df['duration'] >= 300), ['movie_title','director_name']]
# Out:
#                    movie_title        director_name
# 1134             Heaven's Gate       Michael Cimino
# 1487       Blood In, Blood Out      Taylor Hackford
# 1694                   Trapped                  NaN
# 2436                    Carlos                  NaN
# 3254  The Legend of Suriyothai  Chatrichalerm Yukol

# %%
# 3.  감독이름(director_name)이 'Quentin Tarantino' 의 영화들만 조회
df[df['director_name'] == 'Quentin Tarantino']
# Out:
#                movie_title            color      director_name  \
# 293       Django Unchained            Color  Quentin Tarantino
# 582   Inglourious Basterds            Color  Quentin Tarantino
# 698      The Hateful Eight            Color  Quentin Tarantino
# 846      Kill Bill: Vol. 1  Black and White  Quentin Tarantino
# 849      Kill Bill: Vol. 2  Black and White  Quentin Tarantino
# 2883          Jackie Brown            Color  Quentin Tarantino
# 3295          Pulp Fiction            Color  Quentin Tarantino
# 4395        Reservoir Dogs            Color  Quentin Tarantino
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 293                    765.0     165.0                  16000.0
# 582                    486.0     153.0                  16000.0
# 698                    596.0     187.0                  16000.0
# 846                    354.0     111.0                  16000.0
# 849                    304.0     137.0                  16000.0
# ...

# %%
# 4. James Cameron의 영화중 상영시간이 150분 이상인 영화들의 제목(movie_title), 상영시간(duration), 컬러여부(color) 조회

df.loc[(df['director_name'] =='James Cameron') & (df['duration']>=150), ['movie_title','duration','color']]
# Out:
#                      movie_title  duration  color
# 0                         Avatar     178.0  Color
# 26                       Titanic     194.0  Color
# 285   Terminator 2: Judgment Day     153.0  Color
# 599                    The Abyss     171.0  Color
# 2455                      Aliens     154.0  Color

# %% [markdown]
# ## query() 를 이용한 boolean indexing
# - query(조회조건)
#     - sql의 where 절의 조건 처럼 문자열의 query statement를 이용해 조건으로 조회
#     - boolean index에 비해
#         - 장점: 편의성(문자열로 query statement를 만들므로 동적 구문 생성등 다양한 처리가 가능)과 가독성이 좋다.
#         - 단점: 속도가 느리다.
# - 조회조건 구문
#     - `"컬럼명 연산자 비교값"`
# - 외부변수를 이용해 query문의 비교값을 지정할 수 있다.
#     - query 문자열 안에서 @변수명 사용
#     - f string이나 format() 함수를 이용해 query를 만들 수도 있다.

# %% [markdown]
# ### query 함수 연산자
# - **비교 연산자**
#     - ==, \>, \>=, \<, \<=, !=
# - **결측치 비교**
#     - 컬럼.isna(), isnull()
#     - 컬럼.notna(), notnull()
# - **논리 연산자**
#     - and, or, not
# - **in 연산자**
#     - in, ==
#     - not in, !=
#     - 비교 대상값은 리스트에 넣는다.
# - **Index name으로 검색**
#     - 행의 index 이름으로 검색
# - **문자열 부분검색(sql의 like)**
#     - 컬럼명.str.contains(문자열): 문자열을 포함하고 있는
#     - 컬럼명.str.startswith(문자열): 문자열로 시작하는
#     - 컬럼명.str.endswith(문자열): 문자열로 끝나는
#     - **문자열 부분검색을 할 컬럼에 결측치(NaN)이 있으면 안된다.**

# %%
import pandas as pd
import numpy as np
data_dict = {
    'name':['김영수', '박영희', '오준호', '조민경', '박영희', '김영수'],
    'age':[23, 17, 28, 31, 23, 17],
    'email':['s@gmail.com', 'pyh@gmail.com', 'ojh@daum.net', 'cmk@naver.com', 'pyh@daum.net', np.nan]
}
df = pd.DataFrame(data_dict)
df
# Out:
#   name  age          email
# 0  김영수   23    s@gmail.com
# 1  박영희   17  pyh@gmail.com
# 2  오준호   28   ojh@daum.net
# 3  조민경   31  cmk@naver.com
# 4  박영희   23   pyh@daum.net
# 5  김영수   17            NaN

# %%
# 비교연산
# 나이가 17세인 사람
# df[df['age'] == 17]
df.query('age==17') # 조회대상데이터프레임.query('컬럼명 == 비교값')
df.query('age>25')
df.query('age!=17')
# Out:
#   name  age          email
# 0  김영수   23  kys@gmail.com
# 2  오준호   28   ojh@daum.net
# 3  조민경   31  cmk@naver.com
# 4  박영희   23   pyh@daum.net

# %%
# 결측치가 있는 행
df.query('email.isna()') # 대상컬럼.isnull(),isna()
df.query('email.isnull()')
# Out:
#   name  age email
# 5  김영수   17   NaN

# %%
# 결측치가 없는 행
df.query('email.notna()')
df.query('email.notnull()')
# Out:
#   name  age          email
# 0  김영수   23  kys@gmail.com
# 1  박영희   17  pyh@gmail.com
# 2  오준호   28   ojh@daum.net
# 3  조민경   31  cmk@naver.com
# 4  박영희   23   pyh@daum.net

# %%
# 논리연산 -> and, or, not 을 사용가능. (&,|, ~ 사용가능.)
df.query('not age<25')
df.query('~(age<25)')
# Out:
#   name  age          email
# 2  오준호   28   ojh@daum.net
# 3  조민경   31  cmk@naver.com

# %%
df.query('name=="박영희" and age>20') # 비교값이 문자열(str) 일때는 따옴표로 묶어준다.
df.query('(name=="박영희") & (age>20)') # query 메소드에서는 기로 비교연산을 할때 ()로 피연산자 안묶어도 된다.
# Out:
#   name  age         email
# 4  박영희   23  pyh@daum.net

# %%
# 나이가 17 이거나 23인 행을 조회
df.query('age==17 or age==23') # 동일한 컬럼으로 여러개의 값과 == 비교.
df.query('age == [17,23]')
df.query('age in [17,23]')
# Out:
#   name  age          email
# 0  김영수   23  kys@gmail.com
# 1  박영희   17  pyh@gmail.com
# 4  박영희   23   pyh@daum.net
# 5  김영수   17            NaN

# %%
# 나이가 17 이거나 23이 아닌 행을 조회
df.query('age!=17 and age!=23') # 동일한 컬럼으로 여러개의 값과 == 비교.
df.query('age != [17,23]')
df.query('age not in [17,23]')
# Out:
#   name  age          email
# 2  오준호   28   ojh@daum.net
# 3  조민경   31  cmk@naver.com

# %%
# index 이름으로 조건 지정. ==> index 키워드 사용.
# index 이름이 3인 행을 조회
df.query('index == 3') # 데이터프레임으로 반환
# Out:
#   name  age          email
# 3  조민경   31  cmk@naver.com

# %%
df.query('index in [1,3,4]')
# Out:
#   name  age          email
# 1  박영희   17  pyh@gmail.com
# 3  조민경   31  cmk@naver.com
# 4  박영희   23   pyh@daum.net

# %%
# 문자열컬럼값과 부분 일치 조회
# 성이 김씨인 행 조회
df.query('name.str.startswith("김")')  # name 컬럼의 값들 중 '김'으로 시작하는 행
# Out:
#   name  age          email
# 0  김영수   23  kys@gmail.com
# 5  김영수   17            NaN

# %%
# 이름이 영희 행을 조회
df.query('name.str.endswith("영희")') # name 컬럼의 값들 중 '영희' 로 끝나는 행
df.query('name.str.contains("영희")') # name 컬럼의 값들 중 '영희' 를 포함한 행
# Out:
#   name  age          email
# 1  박영희   17  pyh@gmail.com
# 4  박영희   23   pyh@daum.net

# %%
# 이메일주소가 com으로 끝나는 행들
# 문자열 부분일치 조회 -> 결측치가 있는 행은 조회가 힘듬(ValueError 발생)
df.query('email.str.endswith("com")')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4473 try:
# -> 4474     result = self.loc[res]
#    4475 except ValueError:
#    4476     # when res is multi-dimensional loc raises, but this is sometimes a
#    4477     # valid query
#
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexing.py:1291, in _LocIndexer._getitem_axis(self, key, axis)
#    1290     return self._get_slice_axis(key, axis=axis)
# -> 1291 elif com.is_bool_indexer(key):
# ...

# %%
# 1. email이 결측치가 아닌 행을 조회 -> 2. 조건을 조회
df.query('email.notnull()').query('email.str.endswith("com")')
# (메소드, 함수)chaining - 계속 연결해서 처리 진행.
# Out:
#   name  age          email
# 0  김영수   23  kys@gmail.com
# 1  박영희   17  pyh@gmail.com
# 3  조민경   31  cmk@naver.com

# %%
# 외부변수의 값을 이용해서 query statement를 생성.
name = input('조회할 이름:')
#format 문자열
# df.query(f'name == "{name}"')
df.query('name == @name') # name == 변수_name의 값 ==> 문자열일 경우 따음표 처리를 해준다.
# Out:
# 조회할 이름:박영희
#   name  age          email
# 1  박영희   17  pyh@gmail.com
# 4  박영희   23   pyh@daum.net

# %%
name = input('조회할 이름:')
age = int(input('조회할 나이:')) # 숫자형은 숫자(정수, 실수) 타입으로 변환 한 뒤 처리.
df.query('name == @name and age > @age')
# Out:
# 조회할 이름:박영희
# 조회할 나이:20
#   name  age         email
# 4  박영희   23  pyh@daum.net

# %% [markdown]
# <b style='font-size:2.2em'>TODO</b>
# - movie dataframe을 이용해 query() 메소드를 사용해서 아래 문제를 푸세요.

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# 1. 상영시간이 300분 이상인 영화들만 조회
df.query('duration>=300')
# Out:
#                    movie_title  color        director_name  \
# 1134             Heaven's Gate  Color       Michael Cimino
# 1487       Blood In, Blood Out  Color      Taylor Hackford
# 1694                   Trapped  Color                  NaN
# 2436                    Carlos  Color                  NaN
# 3254  The Legend of Suriyothai  Color  Chatrichalerm Yukol
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 1134                   102.0     325.0                    517.0
# 1487                    12.0     330.0                    138.0
# 1694                    16.0     511.0                      NaN
# 2436                   108.0     334.0                      NaN
# 3254                    31.0     300.0                      6.0
#
#       actor_3_facebook_likes              actor_2_name  \
# 1134                   678.0             Sam Waterston
# 1487                   672.0             Jesse Borrego
# ...

# %%
# 2. 상영시간이 250분 ~ 300분 인 영화들 조회
df.query('duration >= 250 and duration <=300')
# Out:
#                       movie_title  color         director_name  \
# 874             Gods and Generals  Color           Ron Maxwell
# 1150                    Cleopatra  Color  Joseph L. Mankiewicz
# 1556               Apocalypse Now  Color  Francis Ford Coppola
# 1698  Once Upon a Time in America  Color          Sergio Leone
# 1963                   Gettysburg  Color           Ron Maxwell
# 2527      Arn: The Knight Templar  Color          Peter Flinth
# 2687                  The Company  Color                   NaN
# 2922                     Das Boot  Color     Wolfgang Petersen
# 3254     The Legend of Suriyothai  Color   Chatrichalerm Yukol
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 874                     84.0     280.0                     33.0
# 1150                    72.0     251.0                    311.0
# 1556                   261.0     289.0                      0.0
# 1698                   111.0     251.0                      0.0
# ...

# %%
# 3. 컬러영화가 아닌 영화 조회
df.query('color!= "Color"')
# Out:
#                                      movie_title            color  \
# 4     Star Wars: Episode VII - The Force Awakens              NaN
# 111                                 Pearl Harbor  Black and White
# 148                              Die Another Day  Black and White
# 254                                  The Aviator  Black and White
# 269                                          Ali  Black and White
# ...                                          ...              ...
# 4882                                      Clerks  Black and White
# 4888                                     Slacker  Black and White
# 4893                                  The Ridges              NaN
# 4895                        Stories of Our Lives  Black and White
# 4901                                 Tin Can Man  Black and White
#
#           director_name  num_critic_for_reviews  duration  \
# 4           Doug Walker                     NaN       NaN
# ...

# %%
# 4. 이름에 James가 들어가는 감독의 영화조회
df.query('director_name.notna()').query('director_name.str.contains("James")')
# James가 들어가는 감독의 영화 조회시 결측치가 있으면 안됨으로!!
# df.query('director_name.notna()') 로 결측치를 걸러준 다음
# .query('director_name.str.contains("James")')로 'James' 가 들어가는 감독의 영화를 조회한다.
# Out:
#                           movie_title            color  director_name  \
# 0                              Avatar            Color  James Cameron
# 26                            Titanic            Color  James Cameron
# 45                          Furious 7            Color      James Wan
# 95            Guardians of the Galaxy            Color     James Gunn
# 106   Alice Through the Looking Glass            Color    James Bobin
# ...                               ...              ...            ...
# 4539                            Bambi            Color    James Algar
# 4578                      Hoop Dreams            Color    Steve James
# 4771                 Western Religion            Color  James O'Brien
# 4797              Yesterday Was a Lie  Black and White   James Kerwin
# 4883                   Pink Narcissus            Color  James Bidgood
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# ...
