# %% [markdown]
# # 코딩 패턴
#
# 1. 데이터셋을 불러오기 (loading)
# 1. 데이터셋 전처리 작업
# 1. tf.data.Dataset을 구성 (train, validation, test dataset)
# 1. 모델을 구성
# 1. 모델 컴파일 - optimizer, loss function, metrics 설정
# 1. 모델 학습(training)
# 1. 최종 평가

# %%
# import 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers

import numpy as np
import matplotlib.pyplot as plt
import random

random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
def plot_result(hist, loss_min=None, loss_max=None):
    
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(hist.epoch, hist.history['loss'], label="train")
    plt.plot(hist.epoch, hist.history['val_loss'], label='validation')
    plt.title('Loss')
    if loss_min!=None and loss_max!=None:
        plt.ylim(loss_min, loss_max)
        
    plt.xlabel('에폭수')
    plt.ylabel('loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(hist.epoch, hist.history['accuracy'], label='train')
    plt.plot(hist.epoch, hist.history['val_accuracy'], label='validation')
    plt.title('Accuracy')
    plt.xlabel('에폭수')
    plt.ylabel('accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# MNIST 데이터셋 로딩
(train_image, train_label), (test_image, test_label)  = keras.datasets.mnist.load_data()

# 전처리 - X: scaling, y: one hot encoding 처리
y_train = keras.utils.to_categorical(train_label)
y_test = keras.utils.to_categorical(test_label)

X_train = train_image.astype('float32')/255
X_test = test_image.astype('float32')/255

print(y_train.shape, y_test.shape)
print(X_train.dtype, X_test.dtype)
# Out:
# (60000, 10) (10000, 10)
# float32 float32

# %%
# 하이퍼파리미터
LEARNING_RATE = 0.001
N_EPOCH = 20
N_BATCH = 1000

# %%
# Dataset 생성
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                               .shuffle(60000).batch(N_BATCH, drop_remainder=True)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCH)

print(len(train_dataset), len(test_dataset))
# Out:
# 60 10

# %% [markdown]
# # 모델의 크기 변경 -> 성능 확인

# %%
def get_small_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28))) # Input Layer + flatten layer
    model.add(layers.Dense(10, activation='softmax', name='output_layer')) # output layer
    
    model.compile(optimizer=optimizers.Adam(learning_rate=LEARNING_RATE), 
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
small_model = get_small_model()
small_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  output_layer (Dense)        (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = small_model.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 1s 9ms/step - loss: 1.4352 - accuracy: 0.6423 - val_loss: 0.8693 - val_accuracy: 0.8311
# Epoch 2/20
# 60/60 [==============================] - 0s 7ms/step - loss: 0.7308 - accuracy: 0.8426 - val_loss: 0.5948 - val_accuracy: 0.8693
# Epoch 3/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.5609 - accuracy: 0.8684 - val_loss: 0.4907 - val_accuracy: 0.8869
# Epoch 4/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.4829 - accuracy: 0.8806 - val_loss: 0.4349 - val_accuracy: 0.8930
# Epoch 5/20
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4369 - accuracy: 0.8892 - val_loss: 0.3995 - val_accuracy: 0.8996
# Epoch 6/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.4061 - accuracy: 0.8949 - val_loss: 0.3752 - val_accuracy: 0.9050
# Epoch 7/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.3837 - accuracy: 0.8996 - val_loss: 0.3574 - val_accuracy: 0.9068
# Epoch 8/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3670 - accuracy: 0.9027 - val_loss: 0.3438 - val_accuracy: 0.9094
# Epoch 9/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.3534 - accuracy: 0.9056 - val_loss: 0.3330 - val_accuracy: 0.9110
# Epoch 10/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3426 - accuracy: 0.9082 - val_loss: 0.3242 - val_accuracy: 0.9121
# Epoch 11/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3336 - accuracy: 0.9097 - val_loss: 0.3171 - val_accuracy: 0.9135
# Epoch 12/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3258 - accuracy: 0.9116 - val_loss: 0.3112 - val_accuracy: 0.9144
# Epoch 13/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.3194 - accuracy: 0.9137 - val_loss: 0.3065 - val_accuracy: 0.9148
# Epoch 14/20
# 60/60 [==============================] - 0s 7ms/step - loss: 0.3137 - accuracy: 0.9144 - val_loss: 0.3026 - val_accuracy: 0.9157
# Epoch 15/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3086 - accuracy: 0.9153 - val_loss: 0.2970 - val_accuracy: 0.9188
# Epoch 16/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.3040 - accuracy: 0.9169 - val_loss: 0.2941 - val_accuracy: 0.9184
# Epoch 17/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3004 - accuracy: 0.9175 - val_loss: 0.2911 - val_accuracy: 0.9187
# Epoch 18/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2965 - accuracy: 0.9182 - val_loss: 0.2888 - val_accuracy: 0.9206
# Epoch 19/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2933 - accuracy: 0.9193 - val_loss: 0.2869 - val_accuracy: 0.9213
# Epoch 20/20
# 60/60 [==============================] - 1s 7ms/step - loss: 0.2903 - accuracy: 0.9204 - val_loss: 0.2848 - val_accuracy: 0.9214

# %%
# 시각화
plot_result(hist)#, 0.25, 0.5)

# %%
def get_big_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28))) # Input Layer + flatten layer
    # hidden layer 추가
    model.add(layers.Dense(512, activation='relu'))
    
    
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    
    model.add(layers.Dense(10, activation='softmax', name='output_layer')) # output layer
    
    model.compile(optimizer=optimizers.Adam(learning_rate=LEARNING_RATE), 
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
big_model = get_big_model()
big_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  output_layer (Dense)        (None, 10)                650
#
# =================================================================
# Total params: 924,170
# Trainable params: 924,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = big_model.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 4s 48ms/step - loss: 0.6680 - accuracy: 0.7776 - val_loss: 0.2042 - val_accuracy: 0.9387
# Epoch 2/20
# 60/60 [==============================] - 3s 44ms/step - loss: 0.1531 - accuracy: 0.9547 - val_loss: 0.1296 - val_accuracy: 0.9606
# Epoch 3/20
# 60/60 [==============================] - 3s 45ms/step - loss: 0.0958 - accuracy: 0.9714 - val_loss: 0.0907 - val_accuracy: 0.9725
# Epoch 4/20
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0650 - accuracy: 0.9805 - val_loss: 0.0837 - val_accuracy: 0.9742
# Epoch 5/20
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0484 - accuracy: 0.9855 - val_loss: 0.0788 - val_accuracy: 0.9753
# Epoch 6/20
# 60/60 [==============================] - 5s 80ms/step - loss: 0.0363 - accuracy: 0.9891 - val_loss: 0.0668 - val_accuracy: 0.9798
# Epoch 7/20
# 60/60 [==============================] - 5s 76ms/step - loss: 0.0307 - accuracy: 0.9900 - val_loss: 0.0717 - val_accuracy: 0.9767
# Epoch 8/20
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.0849 - val_accuracy: 0.9751
# Epoch 9/20
# 60/60 [==============================] - 5s 85ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0811 - val_accuracy: 0.9772
# Epoch 10/20
# 60/60 [==============================] - 5s 79ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0807 - val_accuracy: 0.9806
# Epoch 11/20
# 60/60 [==============================] - 5s 75ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.0784 - val_accuracy: 0.9811
# Epoch 12/20
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0774 - val_accuracy: 0.9787
# Epoch 13/20
# 60/60 [==============================] - 4s 58ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0906 - val_accuracy: 0.9760
# Epoch 14/20
# 60/60 [==============================] - 4s 60ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0807 - val_accuracy: 0.9799
# Epoch 15/20
# 60/60 [==============================] - 3s 56ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0854 - val_accuracy: 0.9807
# Epoch 16/20
# 60/60 [==============================] - 3s 53ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0855 - val_accuracy: 0.9805
# Epoch 17/20
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0835 - val_accuracy: 0.9814
# Epoch 18/20
# 60/60 [==============================] - 3s 46ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.1052 - val_accuracy: 0.9780
# Epoch 19/20
# 60/60 [==============================] - 3s 47ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1127 - val_accuracy: 0.9752
# Epoch 20/20
# 60/60 [==============================] - 3s 50ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0805 - val_accuracy: 0.9817

# %%
plot_result(hist, 0.05, 0.15)

# %%
print(small_model.evaluate(test_dataset))
print(big_model.evaluate(test_dataset))
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.9214
# [0.2848351001739502, 0.9214000105857849]
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0805 - accuracy: 0.9817
# [0.08046633750200272, 0.9817000031471252]

# %% [markdown]
# # Dropout Layer

# %%
# Dropout Layer는 Dropout을 설정하려는 Layer 앞에 먼저 정의한다.
def get_dropout_model():
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28))) # Input Layer + flatten layer
    # hidden layer 추가
    
#     rate = 0.5
    
    model.add(layers.Dropout(rate=0.5))   #drop out 노드의 비율을 지정.
    model.add(layers.Dense(512, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(256, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(256, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(128, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(128, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(64, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(64, activation='relu'))
    
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(10, activation='softmax', name='output_layer')) # output layer
    
    model.compile(optimizer=optimizers.Adam(learning_rate=LEARNING_RATE), 
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
dropout_model = get_dropout_model()
dropout_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dropout_18 (Dropout)        (None, 784)               0
#
#  dense_24 (Dense)            (None, 512)               401920
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 256)               131328
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 256)               65792
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 128)               32896
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 128)               16512
#
#  dropout_24 (Dropout)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 64)                8256
#
#  dropout_25 (Dropout)        (None, 64)                0
#
#  dense_31 (Dense)            (None, 64)                4160
#
#  dropout_26 (Dropout)        (None, 64)                0
#
#  output_layer (Dense)        (None, 10)                650
#
# =================================================================
# Total params: 924,170
# Trainable params: 924,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = dropout_model.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 6s 75ms/step - loss: 2.3144 - accuracy: 0.1204 - val_loss: 2.3015 - val_accuracy: 0.1135
# Epoch 2/20
# 60/60 [==============================] - 4s 72ms/step - loss: 2.2229 - accuracy: 0.1834 - val_loss: 2.1214 - val_accuracy: 0.2230
# Epoch 3/20
# 60/60 [==============================] - 4s 73ms/step - loss: 2.0329 - accuracy: 0.2290 - val_loss: 2.0265 - val_accuracy: 0.2654
# Epoch 4/20
# 60/60 [==============================] - 4s 71ms/step - loss: 1.8768 - accuracy: 0.2687 - val_loss: 1.7526 - val_accuracy: 0.3143
# Epoch 5/20
# 60/60 [==============================] - 6s 93ms/step - loss: 1.6984 - accuracy: 0.3421 - val_loss: 1.7106 - val_accuracy: 0.3331
# Epoch 6/20
# 60/60 [==============================] - 6s 101ms/step - loss: 1.5494 - accuracy: 0.3853 - val_loss: 1.4455 - val_accuracy: 0.4188
# Epoch 7/20
# 60/60 [==============================] - 6s 90ms/step - loss: 1.3915 - accuracy: 0.4355 - val_loss: 1.2295 - val_accuracy: 0.5053
# Epoch 8/20
# 60/60 [==============================] - 6s 90ms/step - loss: 1.2928 - accuracy: 0.4948 - val_loss: 1.1410 - val_accuracy: 0.5215
# Epoch 9/20
# 60/60 [==============================] - 6s 91ms/step - loss: 1.1925 - accuracy: 0.5512 - val_loss: 1.0228 - val_accuracy: 0.5272
# Epoch 10/20
# 60/60 [==============================] - 6s 93ms/step - loss: 1.1059 - accuracy: 0.5863 - val_loss: 0.8470 - val_accuracy: 0.6834
# Epoch 11/20
# 60/60 [==============================] - 5s 84ms/step - loss: 1.0062 - accuracy: 0.6201 - val_loss: 0.7540 - val_accuracy: 0.7220
# Epoch 12/20
# 60/60 [==============================] - 6s 90ms/step - loss: 0.9380 - accuracy: 0.6481 - val_loss: 0.6995 - val_accuracy: 0.7204
# Epoch 13/20
# 60/60 [==============================] - 5s 84ms/step - loss: 0.8848 - accuracy: 0.6711 - val_loss: 0.6601 - val_accuracy: 0.7623
# Epoch 14/20
# 60/60 [==============================] - 5s 78ms/step - loss: 0.8506 - accuracy: 0.6860 - val_loss: 0.6176 - val_accuracy: 0.7789
# Epoch 15/20
# 60/60 [==============================] - 5s 78ms/step - loss: 0.8160 - accuracy: 0.7015 - val_loss: 0.6244 - val_accuracy: 0.7576
# Epoch 16/20
# 60/60 [==============================] - 5s 80ms/step - loss: 0.7842 - accuracy: 0.7171 - val_loss: 0.5762 - val_accuracy: 0.7835
# Epoch 17/20
# 60/60 [==============================] - 5s 80ms/step - loss: 0.7554 - accuracy: 0.7280 - val_loss: 0.5562 - val_accuracy: 0.7888
# Epoch 18/20
# 60/60 [==============================] - 5s 79ms/step - loss: 0.7251 - accuracy: 0.7406 - val_loss: 0.5048 - val_accuracy: 0.8149
# Epoch 19/20
# 60/60 [==============================] - 5s 83ms/step - loss: 0.7129 - accuracy: 0.7534 - val_loss: 0.4851 - val_accuracy: 0.8314
# Epoch 20/20
# 60/60 [==============================] - 5s 77ms/step - loss: 0.6883 - accuracy: 0.7702 - val_loss: 0.4284 - val_accuracy: 0.8478

# %%
plot_result(hist)

# %% [markdown]
# # Batch Normalization 예제

# %%
def get_model_bn(lr=0.01):
    
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    
    # Hidden layer
    # (Dropout Layer ->) Dense Layer -> Batch Normalization -> ReLU(Activation)
    model.add(layers.Dense(256))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    
    model.add(layers.Dense(256))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    
    model.add(layers.Dense(128))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    
    model.add(layers.Dense(128))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    
    # output layer
    model.add(layers.Dense(10))
    model.add(layers.Softmax())
#     model.add(layers.Activation("sigmoid"))
#     layers.Activation('relu') # relu
#     layers.Activation('softmax') # softmax

    # 컴파일
    model.compile(optimizer=optimizers.Adam(learning_rate=lr), 
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model_bn = get_model_bn(LEARNING_RATE)
model_bn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 256)               200960
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  re_lu (ReLU)                (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 320,522
# Trainable params: 318,986
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
hist = model_bn.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 4s 31ms/step - loss: 0.4151 - accuracy: 0.8830 - val_loss: 0.9076 - val_accuracy: 0.9471
# Epoch 2/20
# 60/60 [==============================] - 1s 23ms/step - loss: 0.1065 - accuracy: 0.9704 - val_loss: 0.3555 - val_accuracy: 0.9625
# Epoch 3/20
# 60/60 [==============================] - 2s 24ms/step - loss: 0.0590 - accuracy: 0.9848 - val_loss: 0.1566 - val_accuracy: 0.9685
# Epoch 4/20
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0347 - accuracy: 0.9916 - val_loss: 0.1060 - val_accuracy: 0.9726
# Epoch 5/20
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0206 - accuracy: 0.9958 - val_loss: 0.0770 - val_accuracy: 0.9780
# Epoch 6/20
# 60/60 [==============================] - 2s 28ms/step - loss: 0.0120 - accuracy: 0.9983 - val_loss: 0.0737 - val_accuracy: 0.9778
# Epoch 7/20
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0076 - accuracy: 0.9991 - val_loss: 0.0707 - val_accuracy: 0.9785
# Epoch 8/20
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9793
# Epoch 9/20
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0718 - val_accuracy: 0.9780
# Epoch 10/20
# 60/60 [==============================] - 2s 24ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0689 - val_accuracy: 0.9803
# Epoch 11/20
# 60/60 [==============================] - 2s 26ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9807
# Epoch 12/20
# 60/60 [==============================] - 2s 25ms/step - loss: 9.8501e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9812
# Epoch 13/20
# 60/60 [==============================] - 2s 27ms/step - loss: 7.6984e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9812
# Epoch 14/20
# 60/60 [==============================] - 2s 26ms/step - loss: 6.5520e-04 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9809
# Epoch 15/20
# 60/60 [==============================] - 2s 29ms/step - loss: 5.7182e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9816
# Epoch 16/20
# 60/60 [==============================] - 2s 30ms/step - loss: 4.8782e-04 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9810
# Epoch 17/20
# 60/60 [==============================] - 3s 40ms/step - loss: 4.3089e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9818
# Epoch 18/20
# 60/60 [==============================] - 3s 44ms/step - loss: 3.6188e-04 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9813
# Epoch 19/20
# 60/60 [==============================] - 2s 31ms/step - loss: 3.2939e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9814
# Epoch 20/20
# 60/60 [==============================] - 2s 33ms/step - loss: 3.0149e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9817

# %%
plot_result(hist)

# %% [markdown]
# # Learning Rate 변화를 통한 성능개선
#
# ## Learning Rate scheduler 를 이용
# - 특정 step 마다 learning rate를 변경

# %%
# len(train_dataset)  : 1에폭당 step수
lr_scheduler = optimizers.schedules.ExponentialDecay(
    initial_learning_rate=LEARNING_RATE, # 시작(초기) 학습률
    decay_step=len(train_dataset)*5,    # 몇 step마다 변경할 것인지 그 간격  ex) 5 -> 다섯스텝마다 변경.
    decay_rate=0.5, # 변화율 -> 현재 학습율 * decay_rate => 새로운 학습율
    staircase=True  # decay_step때 한번에 변경할 것인지(True). 매 step마다 조금씩 변경할 것인지(False) 여부
)
# Learning rate scheduler를 Optimizer의 Learing rate에 설정.

# %%
def get_model_lr(initial_lr=0.01):
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax', name='output_layer'))
    
    lr_sch = optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_lr, 
                                                   decay_steps=len(train_dataset) * 5, 
                                                   decay_rate=0.5, 
                                                   staircase=True)
    
    model.compile(optimizer=optimizers.Adam(learning_rate=lr_sch),   # Learning rate scheduler를 학습률로 지정.
                  loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model_lr = get_model_lr(LEARNING_RATE)
hist = model_lr.fit(train_dataset, epochs=N_EPOCH, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 2s 18ms/step - loss: 0.6221 - accuracy: 0.8264 - val_loss: 0.2441 - val_accuracy: 0.9281
# Epoch 2/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2104 - accuracy: 0.9390 - val_loss: 0.1757 - val_accuracy: 0.9505
# Epoch 3/20
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1517 - accuracy: 0.9560 - val_loss: 0.1388 - val_accuracy: 0.9583
# Epoch 4/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1155 - accuracy: 0.9668 - val_loss: 0.1116 - val_accuracy: 0.9650
# Epoch 5/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0936 - accuracy: 0.9728 - val_loss: 0.1059 - val_accuracy: 0.9679
# Epoch 6/20
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0729 - accuracy: 0.9792 - val_loss: 0.0917 - val_accuracy: 0.9715
# Epoch 7/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0650 - accuracy: 0.9811 - val_loss: 0.0845 - val_accuracy: 0.9750
# Epoch 8/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0573 - accuracy: 0.9837 - val_loss: 0.0852 - val_accuracy: 0.9745
# Epoch 9/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0516 - accuracy: 0.9857 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 10/20
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0466 - accuracy: 0.9873 - val_loss: 0.0770 - val_accuracy: 0.9760
# Epoch 11/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0400 - accuracy: 0.9894 - val_loss: 0.0760 - val_accuracy: 0.9765
# Epoch 12/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0370 - accuracy: 0.9903 - val_loss: 0.0744 - val_accuracy: 0.9774
# Epoch 13/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0352 - accuracy: 0.9909 - val_loss: 0.0732 - val_accuracy: 0.9776
# Epoch 14/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0328 - accuracy: 0.9916 - val_loss: 0.0742 - val_accuracy: 0.9769
# Epoch 15/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0308 - accuracy: 0.9927 - val_loss: 0.0706 - val_accuracy: 0.9783
# Epoch 16/20
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0281 - accuracy: 0.9935 - val_loss: 0.0707 - val_accuracy: 0.9782
# Epoch 17/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0270 - accuracy: 0.9938 - val_loss: 0.0710 - val_accuracy: 0.9782
# Epoch 18/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0262 - accuracy: 0.9941 - val_loss: 0.0707 - val_accuracy: 0.9784
# Epoch 19/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0253 - accuracy: 0.9946 - val_loss: 0.0715 - val_accuracy: 0.9777
# Epoch 20/20
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0244 - accuracy: 0.9946 - val_loss: 0.0713 - val_accuracy: 0.9784

# %% [markdown]
# ## callback 을 이용해 학습률 변경
# - ReduceLROnPlateau callback을 이용

# %%
tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', # 검증지표 (기본값: val_loss)
                                     factor=0.5,  # 변화율: 현재학습률 * factor = 새학습률  (기본값: 0.1)
                                     patience=5,   # 성능이 개선되는지 확인하는 에폭수(기본값: 10)- 지정한 에폭동안 성능개선이 안되면 학습률을 변경
                                     mode='auto'  # 성능개선이 값이 커지는것인지 작아지는 것이 개선인지 지정. "min", "max", "auto"(기본)
                                    )

# %%
def get_model_lr2(initial_lr=0.01):
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax', name='output_layer'))
    
    model.compile(optimizer=optimizers.Adam(learning_rate=initial_lr),   # Learning rate scheduler를 학습률로 지정.
                  loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model_lr2 = get_model_lr2(LEARNING_RATE)

# %%
lr_callback = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                factor=0.5, 
                                                patience=3, 
                                                verbose=2    #  학습률이 변경될 때 마다 로그를 출력
                                               )

hist = model_lr2.fit(train_dataset, epochs=N_EPOCH+10, validation_data=test_dataset, 
                    callbacks=[lr_callback])
# Out:
# Epoch 1/30
# 60/60 [==============================] - 2s 19ms/step - loss: 0.6427 - accuracy: 0.8265 - val_loss: 0.2384 - val_accuracy: 0.9283 - lr: 0.0010
# Epoch 2/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.1990 - accuracy: 0.9419 - val_loss: 0.1673 - val_accuracy: 0.9494 - lr: 0.0010
# Epoch 3/30
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1424 - accuracy: 0.9586 - val_loss: 0.1312 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 4/30
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1099 - accuracy: 0.9680 - val_loss: 0.1080 - val_accuracy: 0.9654 - lr: 0.0010
# Epoch 5/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0896 - accuracy: 0.9742 - val_loss: 0.1024 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 6/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0735 - accuracy: 0.9783 - val_loss: 0.0893 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 7/30
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0617 - accuracy: 0.9818 - val_loss: 0.0827 - val_accuracy: 0.9749 - lr: 0.0010
# Epoch 8/30
# 60/60 [==============================] - 1s 19ms/step - loss: 0.0505 - accuracy: 0.9854 - val_loss: 0.0820 - val_accuracy: 0.9755 - lr: 0.0010
# Epoch 9/30
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0436 - accuracy: 0.9873 - val_loss: 0.0750 - val_accuracy: 0.9763 - lr: 0.0010
# Epoch 10/30
# 60/60 [==============================] - 1s 19ms/step - loss: 0.0369 - accuracy: 0.9890 - val_loss: 0.0754 - val_accuracy: 0.9780 - lr: 0.0010
# Epoch 11/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0336 - accuracy: 0.9902 - val_loss: 0.0766 - val_accuracy: 0.9757 - lr: 0.0010
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9930
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 0.0785 - val_accuracy: 0.9769 - lr: 0.0010
# Epoch 13/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0186 - accuracy: 0.9952 - val_loss: 0.0709 - val_accuracy: 0.9787 - lr: 5.0000e-04
# Epoch 14/30
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0154 - accuracy: 0.9969 - val_loss: 0.0691 - val_accuracy: 0.9796 - lr: 5.0000e-04
# Epoch 15/30
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0144 - accuracy: 0.9972 - val_loss: 0.0706 - val_accuracy: 0.9793 - lr: 5.0000e-04
# Epoch 16/30
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.0718 - val_accuracy: 0.9795 - lr: 5.0000e-04
# Epoch 17/30
# 59/60 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9980
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.0721 - val_accuracy: 0.9792 - lr: 5.0000e-04
# Epoch 18/30
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 0.0708 - val_accuracy: 0.9793 - lr: 2.5000e-04
# Epoch 19/30
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0085 - accuracy: 0.9989 - val_loss: 0.0716 - val_accuracy: 0.9802 - lr: 2.5000e-04
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9990
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 60/60 [==============================] - 1s 19ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.0722 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 21/30
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0712 - val_accuracy: 0.9800 - lr: 1.2500e-04
# Epoch 22/30
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.0713 - val_accuracy: 0.9799 - lr: 1.2500e-04
# Epoch 23/30
# 58/60 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9993
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 0.0718 - val_accuracy: 0.9802 - lr: 1.2500e-04
# Epoch 24/30
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.0716 - val_accuracy: 0.9797 - lr: 6.2500e-05
# Epoch 25/30
# 60/60 [==============================] - 2s 22ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.0717 - val_accuracy: 0.9800 - lr: 6.2500e-05
# Epoch 26/30
# 59/60 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9994
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 60/60 [==============================] - 2s 24ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.0719 - val_accuracy: 0.9799 - lr: 6.2500e-05
# Epoch 27/30
# 60/60 [==============================] - 2s 28ms/step - loss: 0.0060 - accuracy: 0.9994 - val_loss: 0.0717 - val_accuracy: 0.9798 - lr: 3.1250e-05
# Epoch 28/30
# 60/60 [==============================] - 2s 28ms/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 0.0719 - val_accuracy: 0.9800 - lr: 3.1250e-05
# Epoch 29/30
# 59/60 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9995
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 60/60 [==============================] - 2s 29ms/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 0.0719 - val_accuracy: 0.9800 - lr: 3.1250e-05
# Epoch 30/30
# 60/60 [==============================] - 2s 29ms/step - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.0720 - val_accuracy: 0.9803 - lr: 1.5625e-05
